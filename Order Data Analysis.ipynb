# %%
#to install kaggle
# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#      ---------------------------------------- 82.1/82.1 kB 2.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB 2.0 MB/s eta 0:00:01
# ...

# %%
#to import kaggle libraries
import kaggle
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kaggle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api\kaggle_api_extended.py:398, in KaggleApi.authenticate(self)
#     396         return
#     397     else:
# --> 398         raise IOError('Could not find {}. Make sure it\'s located in'
#     399                       ' {}. Or use the environment method.'.format(
#     400                           self.config_file, self.config_dir))
#     402 # Step 3: load into configuration!
#     403 self._load_config(config_data)
#
# ...

# %%
#to download datasets from kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 422kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 422kB/s]

# %%
#to import csv file and extract it
import zipfile
zip_ref = zipfile.ZipFile("orders.csv.zip")
zip_ref.extractall()
zip_ref.close()

# %%
#to install pandas
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#to install pandas libraries
import pandas as pd

# %%
#to read csv file and change unknown values to null
df = pd.read_csv("orders.csv", na_values = ['Not Available','unknown'])
df.head(10)
#to check unique or distinct values
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#to check names in the columns
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
 #to replace columns in lower case
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['order id', 'order date', 'ship mode', 'segment', 'country', 'city',
#        'state', 'postal code', 'region', 'category', 'sub category',
#        'product id', 'cost price', 'list price', 'quantity',
#        'discount percent'],
#       dtype='object')

# %%
#to replace space and put underscore
df.columns = df.columns.str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
#to view data 
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#to derive new column discount to check exact discounted amount
df['discount']= df['list_price'] * df['discount_percent']/100
df['sale_price']= df['list_price'] - df['discount']
df['profit']= df['sale_price']- df['cost_price']

# %%
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#to change the data type to date from object to datetime
df['order_date'] = pd.to_datetime(df['order_date'], format = '%Y-%m-%d')

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# sale_price                 float64
# profit                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'sale_price', 'profit'],
#       dtype='object')

# %%
df.drop(columns = ['list_price','cost_price','discount_percent'])
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'sale_price', 'profit'],
#       dtype='object')

# %%
#to drop/delete columns
df.drop(columns=['list_price','discount_percent','cost_price',], inplace= True)

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#to load data into sql server
# !pip install pyodbc

from sqlalchemy import create_engine

# Correct connection string format
engine = create_engine('mssql+pyodbc://DESKTOP-MPJT19C/master?driver=ODBC+Driver+17+for+SQL+Server')
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Correct connection string format
engine = create_engine('mssql+pyodbc://DESKTOP-MPJT19C/master?driver=ODBC+Driver+17+for+SQL+Server')
conn = engine.connect()

# %%
#i ran this query again because of loss of connection with the table
import pandas as pd
df = pd.read_csv("orders.csv")

# %%
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df = pd.read_csv("orders.csv", na_values = ['Not Available','unknown'])
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# %%
df.head(20)
# Out:
#     order_id  order_date       ship_mode      segment        country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['discount']= df['list_price'] * df['discount_percent']/100
df['sale_price']= df['list_price'] - df['discount']
df['profit']= df['sale_price']- df['cost_price']

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format = '%Y-%m-%d')

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.drop(columns=['list_price','discount_percent','cost_price',], inplace= True)

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#to load table in sql
df.to_sql('df_orders',con=conn, index=False, if_exists = 'append')
# Out:
# 38
